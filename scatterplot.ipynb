# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=sns.load_dataset('exercise')

# %%
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.scatterplot(x='time',y='id',data=df)
plt.show()

# %%
sns.scatterplot(x='time',y='pulse',data=df)
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.scatterplot(x='time',y='id',data=df,hue='diet')
plt.show()

# %%
sns.scatterplot(x='time',y='id',data=df,hue='kind')
plt.show()

# %%
sns.scatterplot(x='time',y='id',data=df,hue='kind',palette='bright')
plt.show()

# %%
sns.scatterplot(x='time',y='id',data=df,hue='kind',palette='muted')
plt.show()

# %%
sns.scatterplot(x='time',y='id',data=df,hue='kind',palette='bright',size='diet')
plt.show()

# %%
sns.scatterplot(x='time',y='id',data=df,hue='kind',palette='bright',size='diet',markers='size')
plt.show()

# %%
sns.scatterplot(x='time',y='id',data=df,hue='kind',palette='bright',size='diet',alpha=0.5)
plt.show()
